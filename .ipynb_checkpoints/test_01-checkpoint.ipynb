# %%
# Dependency - pandas 3.0
# !pip install pyarrow

# %%
import pandas as pd
import os

# %%
# Windows
wpath = os.getcwd()
wpath
# Out:
# 'C:\\Users\\kiip\\Documents\\github\\doit_pandas'

# %%
# Windows
os.chdir(wpath + '\\data')
os.getcwd()
# Out:
# 'C:\\Users\\kiip\\Documents\\github\\doit_pandas\\data'

# %%
# MacBook
mpath = os.getcwd()
mpath
# Out:
# '/Users/james/Documents/GitHub/doit_pandas'

# %%
# MacBook
os.chdir(mpath + '/data')
os.getcwd()
# Out:
# '/Users/james/Documents/GitHub/doit_pandas/data'

# %%
df_raw = pd.read_csv('gapminder.tsv', sep='\t')
df_raw.head()
# Out:
#        country continent  year  lifeExp       pop   gdpPercap
# 0  Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4  Afghanistan      Asia  1972   36.088  13079460  739.981106

# %%
df = df_raw.copy()
df.head()
# Out:
#        country continent  year  lifeExp       pop   gdpPercap
# 0  Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4  Afghanistan      Asia  1972   36.088  13079460  739.981106

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
country_df = df['country']
country_df
# Out:
# 0       Afghanistan
# 1       Afghanistan
# 2       Afghanistan
# 3       Afghanistan
# 4       Afghanistan
#            ...
# 1699       Zimbabwe
# 1700       Zimbabwe
# 1701       Zimbabwe
# 1702       Zimbabwe
# 1703       Zimbabwe
# Name: country, Length: 1704, dtype: object

# %%
country_df.tail()
# Out:
# 1699    Zimbabwe
# 1700    Zimbabwe
# 1701    Zimbabwe
# 1702    Zimbabwe
# 1703    Zimbabwe
# Name: country, dtype: object

# %%
df.columns
# Out:
# Index(['country', 'continent', 'year', 'lifeExp', 'pop', 'gdpPercap'], dtype='object')

# %%
subset = df[['country', 'continent', 'year']]
subset.head()
# Out:
#        country continent  year
# 0  Afghanistan      Asia  1952
# 1  Afghanistan      Asia  1957
# 2  Afghanistan      Asia  1962
# 3  Afghanistan      Asia  1967
# 4  Afghanistan      Asia  1972

# %%
print(type(country_df))
print(type(subset))
# Out:
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.frame.DataFrame'>

# %%
df.loc[0]
# Out:
# country      Afghanistan
# continent           Asia
# year                1952
# lifeExp           28.801
# pop              8425333
# gdpPercap     779.445314
# Name: 0, dtype: object

# %%
number_of_rows = df.shape[0]
last_row_index = number_of_rows-1
df.loc[last_row_index]
# Out:
# country        Zimbabwe
# continent        Africa
# year               2007
# lifeExp          43.487
# pop            12311143
# gdpPercap    469.709298
# Name: 1703, dtype: object

# %%
subset2 = df.loc[[0,1,2]]
subset2
# Out:
#        country continent  year  lifeExp       pop   gdpPercap
# 0  Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710

# %%
type(subset2)
# Out:
# pandas.core.frame.DataFrame

# %%
subset_loc = df.loc[0]
subset_loc
# Out:
# country      Afghanistan
# continent           Asia
# year                1952
# lifeExp           28.801
# pop              8425333
# gdpPercap     779.445314
# Name: 0, dtype: object

# %%
type(subset_loc)
# Out:
# pandas.core.series.Series

# %%
df.iloc[0]
# Out:
# country      Afghanistan
# continent           Asia
# year                1952
# lifeExp           28.801
# pop              8425333
# gdpPercap     779.445314
# Name: 0, dtype: object

# %%
df.head()
# Out:
#        country continent  year  lifeExp       pop   gdpPercap
# 0  Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4  Afghanistan      Asia  1972   36.088  13079460  739.981106

# %%
print(df.loc[0])
# Out:
# country      Afghanistan
# continent           Asia
# year                1952
# lifeExp           28.801
# pop              8425333
# gdpPercap     779.445314
# Name: 0, dtype: object

# %%
print(df.iloc[0])
# Out:
# country      Afghanistan
# continent           Asia
# year                1952
# lifeExp           28.801
# pop              8425333
# gdpPercap     779.445314
# Name: 0, dtype: object

# %%
# it doesn't work
df.loc[-1]

# %%
df.iloc[-1]
# Out:
# country        Zimbabwe
# continent        Africa
# year               2007
# lifeExp          43.487
# pop            12311143
# gdpPercap    469.709298
# Name: 1703, dtype: object

# %%
df.loc[0, ['year', 'pop']]
# Out:
# year       1952
# pop     8425333
# Name: 0, dtype: object

# %%
df.loc[0][['year','pop']]
# Out:
# year       1952
# pop     8425333
# Name: 0, dtype: object

# %%
df.loc[:, ['year', 'pop']]
# Out:
#       year       pop
# 0     1952   8425333
# 1     1957   9240934
# 2     1962  10267083
# 3     1967  11537966
# 4     1972  13079460
# ...    ...       ...
# 1699  1987   9216418
# 1700  1992  10704340
# 1701  1997  11404948
# 1702  2002  11926563
# 1703  2007  12311143
#
# [1704 rows x 2 columns]

# %%
df.loc[:][['year','pop']]
# Out:
#       year       pop
# 0     1952   8425333
# 1     1957   9240934
# 2     1962  10267083
# 3     1967  11537966
# 4     1972  13079460
# ...    ...       ...
# 1699  1987   9216418
# 1700  1992  10704340
# 1701  1997  11404948
# 1702  2002  11926563
# 1703  2007  12311143
#
# [1704 rows x 2 columns]

# %%
range(5)
# Out:
# range(0, 5)

# %%
list(range(5))
# Out:
# [0, 1, 2, 3, 4]

# %%
small_range = list(range(5))
small_range
# Out:
# [0, 1, 2, 3, 4]

# %%
list(range(5))
# Out:
# [0, 1, 2, 3, 4]

# %%
df.iloc[:, small_range].head()
# Out:
#        country continent  year  lifeExp       pop
# 0  Afghanistan      Asia  1952   28.801   8425333
# 1  Afghanistan      Asia  1957   30.332   9240934
# 2  Afghanistan      Asia  1962   31.997  10267083
# 3  Afghanistan      Asia  1967   34.020  11537966
# 4  Afghanistan      Asia  1972   36.088  13079460

# %%
df.iloc[:, list(range(5))].head()
# Out:
#        country continent  year  lifeExp       pop
# 0  Afghanistan      Asia  1952   28.801   8425333
# 1  Afghanistan      Asia  1957   30.332   9240934
# 2  Afghanistan      Asia  1962   31.997  10267083
# 3  Afghanistan      Asia  1967   34.020  11537966
# 4  Afghanistan      Asia  1972   36.088  13079460

# %%
list(range(0, 6, 2))
# Out:
# [0, 2, 4]

# %%
df.iloc[:, list(range(0,6,2))].head()
# Out:
#        country  year       pop
# 0  Afghanistan  1952   8425333
# 1  Afghanistan  1957   9240934
# 2  Afghanistan  1962  10267083
# 3  Afghanistan  1967  11537966
# 4  Afghanistan  1972  13079460

# %%
df.iloc[:, :3].head()
# Out:
#        country continent  year
# 0  Afghanistan      Asia  1952
# 1  Afghanistan      Asia  1957
# 2  Afghanistan      Asia  1962
# 3  Afghanistan      Asia  1967
# 4  Afghanistan      Asia  1972

# %%
df.iloc[:, 0:6:2].head()
# Out:
#        country  year       pop
# 0  Afghanistan  1952   8425333
# 1  Afghanistan  1957   9240934
# 2  Afghanistan  1962  10267083
# 3  Afghanistan  1967  11537966
# 4  Afghanistan  1972  13079460

# %%
df.iloc[0:6:2, 0:6:2]
# Out:
#        country  year       pop
# 0  Afghanistan  1952   8425333
# 2  Afghanistan  1962  10267083
# 4  Afghanistan  1972  13079460

# %%
df.loc[[0,99,999], ['country', 'lifeExp', 'gdpPercap']]
# Out:
#          country  lifeExp    gdpPercap
# 0    Afghanistan   28.801   779.445314
# 99    Bangladesh   43.453   721.186086
# 999     Mongolia   51.253  1226.041130

# %%
df.loc[10:13, ['country', 'lifeExp', 'gdpPercap']]
# Out:
#         country  lifeExp    gdpPercap
# 10  Afghanistan   42.129   726.734055
# 11  Afghanistan   43.828   974.580338
# 12      Albania   55.230  1601.056136
# 13      Albania   59.280  1942.284244

# %%
df.iloc[10:13, [0,3,5]]
# Out:
#         country  lifeExp    gdpPercap
# 10  Afghanistan   42.129   726.734055
# 11  Afghanistan   43.828   974.580338
# 12      Albania   55.230  1601.056136

# %%
df.head()
# Out:
#        country continent  year  lifeExp       pop   gdpPercap
# 0  Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4  Afghanistan      Asia  1972   36.088  13079460  739.981106

# %%
df.groupby('year')['lifeExp'].mean().head()
# Out:
# year
# 1952    49.057620
# 1957    51.507401
# 1962    53.609249
# 1967    55.678290
# 1972    57.647386
# Name: lifeExp, dtype: float64

# %%
type(df.groupby('year')['lifeExp'].mean())
# Out:
# pandas.core.series.Series

# %%
df.groupby('year', as_index=False)['lifeExp'].mean().head()
# Out:
#    year    lifeExp
# 0  1952  49.057620
# 1  1957  51.507401
# 2  1962  53.609249
# 3  1967  55.678290
# 4  1972  57.647386

# %%
type(df.groupby('year', as_index=False)['lifeExp'].mean().head())
# Out:
# pandas.core.frame.DataFrame

# %%
df.groupby('year', as_index=False) \
  .agg(mean_lifeExp = ('lifeExp', 'mean')) \
  .sort_values('year') \
  .head()
# Out:
#    year  mean_lifeExp
# 0  1952     49.057620
# 1  1957     51.507401
# 2  1962     53.609249
# 3  1967     55.678290
# 4  1972     57.647386

# %%
df.groupby(['year', 'continent'])[['lifeExp', 'gdpPercap']].mean().head(10)
# Out:
#                   lifeExp     gdpPercap
# year continent
# 1952 Africa     39.135500   1252.572466
#      Americas   53.279840   4079.062552
#      Asia       46.314394   5195.484004
#      Europe     64.408500   5661.057435
#      Oceania    69.255000  10298.085650
# 1957 Africa     41.266346   1385.236062
#      Americas   55.960280   4616.043733
#      Asia       49.318544   5787.732940
#      Europe     66.703067   6963.012816
#      Oceania    70.295000  11598.522455

# %%
df.groupby(['year', 'continent'])[['lifeExp', 'gdpPercap']] \
  .mean().head(10)
# Out:
#                   lifeExp     gdpPercap
# year continent
# 1952 Africa     39.135500   1252.572466
#      Americas   53.279840   4079.062552
#      Asia       46.314394   5195.484004
#      Europe     64.408500   5661.057435
#      Oceania    69.255000  10298.085650
# 1957 Africa     41.266346   1385.236062
#      Americas   55.960280   4616.043733
#      Asia       49.318544   5787.732940
#      Europe     66.703067   6963.012816
#      Oceania    70.295000  11598.522455

# %%
df.groupby(['year','continent'], as_index=False) \
  .agg(mean_lifeExp = ('lifeExp','mean'),
       mean_gdpPercap = ('gdpPercap','mean')) \
  .sort_values(['year','continent']) \
  .head(10)
# Out:
#    year continent  mean_lifeExp  mean_gdpPercap
# 0  1952    Africa     39.135500     1252.572466
# 1  1952  Americas     53.279840     4079.062552
# 2  1952      Asia     46.314394     5195.484004
# 3  1952    Europe     64.408500     5661.057435
# 4  1952   Oceania     69.255000    10298.085650
# 5  1957    Africa     41.266346     1385.236062
# 6  1957  Americas     55.960280     4616.043733
# 7  1957      Asia     49.318544     5787.732940
# 8  1957    Europe     66.703067     6963.012816
# 9  1957   Oceania     70.295000    11598.522455

# %%
df.groupby('continent').nunique()
# Out:
#            country  year  lifeExp  pop  gdpPercap
# continent
# Africa          52    12      619  624        624
# Americas        25    12      299  300        300
# Asia            33    12      393  396        396
# Europe          30    12      326  360        360
# Oceania          2    12       24   24         24

# %%
df['pop'].mean()
# Out:
# 29601212.324530516

# %%
df.count()
# Out:
# country      1704
# continent    1704
# year         1704
# lifeExp      1704
# pop          1704
# gdpPercap    1704
# dtype: int64

# %%
df.nunique()
# Out:
# country       142
# continent       5
# year           12
# lifeExp      1626
# pop          1704
# gdpPercap    1704
# dtype: int64

# %%
df['continent'].nunique()
# Out:
# 5

# %%
df.groupby('continent')['country'].nunique()
# Out:
# continent
# Africa      52
# Americas    25
# Asia        33
# Europe      30
# Oceania      2
# Name: country, dtype: int64

# %%
df.groupby('continent').count()
# Out:
#            country  year  lifeExp  pop  gdpPercap
# continent
# Africa         624   624      624  624        624
# Americas       300   300      300  300        300
# Asia           396   396      396  396        396
# Europe         360   360      360  360        360
# Oceania         24    24       24   24         24

# %%
df.groupby('continent')['country'].count()
# Out:
# continent
# Africa      624
# Americas    300
# Asia        396
# Europe      360
# Oceania      24
# Name: country, dtype: int64

# %%
df.groupby('continent', as_index=False) \
  .agg(n_country = ('country', 'count')) \
  .sort_values('n_country')
# Out:
#   continent  n_country
# 4   Oceania         24
# 1  Americas        300
# 3    Europe        360
# 2      Asia        396
# 0    Africa        624

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
df_subset = df.groupby('year')['lifeExp'].mean()
df_subset
# Out:
# year
# 1952    49.057620
# 1957    51.507401
# 1962    53.609249
# 1967    55.678290
# 1972    57.647386
# 1977    59.570157
# 1982    61.533197
# 1987    63.212613
# 1992    64.160338
# 1997    65.014676
# 2002    65.694923
# 2007    67.007423
# Name: lifeExp, dtype: float64

# %%
df_subset.plot();

# %%
df_subset.plot.line();

# %%
df_subset.plot.line(rot=45);

# %%
df_subset.plot.bar(rot=45);

# %%
# !pip install xlwt openpyxl
# Out:
# ...
#   Using cached xlwt-1.3.0-py2.py3-none-any.whl (99 kB)
# ...
#   Using cached openpyxl-3.1.2-py2.py3-none-any.whl.metadata (2.5 kB)
# ...
#   Using cached et_xmlfile-1.1.0-py3-none-any.whl.metadata (1.8 kB)
# Using cached openpyxl-3.1.2-py2.py3-none-any.whl (249 kB)
# Using cached et_xmlfile-1.1.0-py3-none-any.whl (4.7 kB)
# ...

# %%
import pandas as pd
import os
from collections import OrderedDict
import random
import xlwt
import openpyxl

# %%
s1 = pd.Series(['banana', 42])
s1
# Out:
# 0    banana
# 1        42
# dtype: object

# %%
print(s1[0])
print(s1[1])
# Out:
# banana
# 42

# %%
s_index = pd.Series(['James', 'Data Scientist'], index=['Person', 'Job'])
s_index
# Out:
# Person             James
# Job       Data Scientist
# dtype: object

# %%
pd.DataFrame({'col1' : ['data1', 'data2'], 'col2' : ['data3', 'data4']})
# Out:
#     col1   col2
# 0  data1  data3
# 1  data2  data4

# %%
df_scientists = pd.DataFrame({'Name' : ['R. Franklin', 'W. Gosset'],
                              'Occupation' : ['Chemist', 'Statistician'],
                              'Born' : ['1920-07-25', '1876-06-13'],
                              'Died' : ['1958-04-16', '1937-10-16'],
                              'Age'  : [37, 61]})
df_scientists
# Out:
#           Name    Occupation        Born        Died  Age
# 0  R. Franklin       Chemist  1920-07-25  1958-04-16   37
# 1    W. Gosset  Statistician  1876-06-13  1937-10-16   61

# %%
df_idx_scientists = pd.DataFrame(data = {'Name' : ['R. Franklin', 'W. Gosset'],
                                         'Occupation' : ['Chemist', 'Statistician'],
                                         'Born' : ['1920-07-25', '1876-06-13'],
                                         'Died' : ['1958-04-16', '1937-10-16'],
                                         'Age'  : [37, 61]},
                                index = ['Person1', 'Person2'])
df_idx_scientists
# Out:
#                 Name    Occupation        Born        Died  Age
# Person1  R. Franklin       Chemist  1920-07-25  1958-04-16   37
# Person2    W. Gosset  Statistician  1876-06-13  1937-10-16   61

# %%
df_ord_scientists = pd.DataFrame(data = {'Name' : ['R. Franklin', 'W. Gosset'],
                                          'Occupation' : ['Chemist', 'Statistician'],
                                          'Born' : ['1920-07-25', '1876-06-13'],
                                          'Died' : ['1958-04-16', '1937-10-16'],
                                          'Age'  : [37, 61]},
                                 columns = ['Occupation', 'Name', 'Age', 'Born', 'Died'])
df_ord_scientists
# Out:
#      Occupation         Name  Age        Born        Died
# 0       Chemist  R. Franklin   37  1920-07-25  1958-04-16
# 1  Statistician    W. Gosset   61  1876-06-13  1937-10-16

# %%
from collections import OrderedDict

# %%
import pandas as pd
import os
from collections import OrderedDict
# Out:
# The history saving thread hit an unexpected error (OperationalError('attempt to write a readonly database')).History will not be written to the database.

# %%
path = os.getcwd()
path
# Out:
# '/Users/james/Documents/GitHub/doit_pandas'

# %%
os.chdir(path + '/data/')
os.getcwd()
# Out:
# '/Users/james/Documents/GitHub/doit_pandas/data'

# %%
df_raw = pd.read_csv('gapminder.tsv', sep='\t')
df_raw.head()
# Out:
#        country continent  year  lifeExp       pop   gdpPercap
# 0  Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4  Afghanistan      Asia  1972   36.088  13079460  739.981106

# %%
df = df_raw.copy()
df.head()
# Out:
#        country continent  year  lifeExp       pop   gdpPercap
# 0  Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4  Afghanistan      Asia  1972   36.088  13079460  739.981106

# %%
df.groupby('year')[['lifeExp', 'pop']].mean().head()
# Out:
#         lifeExp           pop
# year
# 1952  49.057620  1.695040e+07
# 1957  51.507401  1.876341e+07
# 1962  53.609249  2.042101e+07
# 1967  55.678290  2.265830e+07
# 1972  57.647386  2.518998e+07

# %%
df.groupby('year', as_index=False) \
  .agg(mean_lifeExp = ('lifeExp', 'mean'),
       mean_pop = ('pop', 'mean')) \
  .sort_values('year') \
  .head()
# Out:
#    year  mean_lifeExp      mean_pop
# 0  1952     49.057620  1.695040e+07
# 1  1957     51.507401  1.876341e+07
# 2  1962     53.609249  2.042101e+07
# 3  1967     55.678290  2.265830e+07
# 4  1972     57.647386  2.518998e+07

# %%
scientists = pd.DataFrame(data = {'Occupation' : ['Chem', 'Stat'],
                                  'Born' : ['1920-07-25', '1876-06-13'],
                                  'Died' : ['1958-04-16', '1937-10-16'],
                                  'Age' : [37, 61]},
                          index = ['R.Frank', 'W. Gosset'],
                          columns = ['Occupation', 'Age', 'Born', 'Died'])
scientists
# Out:
#           Occupation  Age        Born        Died
# R.Frank         Chem   37  1920-07-25  1958-04-16
# W. Gosset       Stat   61  1876-06-13  1937-10-16

# %%
from collections import OrderedDict

# %%
scientists_ordered = pd.DataFrame(OrderedDict([
    ('Name', ['R. Frank', 'W. Gosset']),
    ('Occupation', ['Chem', 'Stat'])]))
scientists_ordered
# Out:
#         Name Occupation
# 0   R. Frank       Chem
# 1  W. Gosset       Stat

# %%
scientists = pd.DataFrame(
    data = {'Occupation' : ['Chemist', 'Statistician'],
            'Born' : ['1920-07-25', '1876-06-13'],
            'Died' : ['1958-04-16', '1937-10-16'],
            'Age' : [37, 61]}, 
    index = ['Rosaline Franklin', 'William Gosset'],
    columns = ['Occupation', 'Born', 'Died', 'Age'])

scientists
# Out:
#                      Occupation        Born        Died  Age
# Rosaline Franklin       Chemist  1920-07-25  1958-04-16   37
# William Gosset     Statistician  1876-06-13  1937-10-16   61

# %%
first_row = scientists.loc['William Gosset']
first_row
# Out:
# Occupation    Statistician
# Born            1876-06-13
# Died            1937-10-16
# Age                     61
# Name: William Gosset, dtype: object

# %%
type(first_row)
# Out:
# pandas.core.series.Series

# %%
first_row.index
# Out:
# Index(['Occupation', 'Born', 'Died', 'Age'], dtype='object')

# %%
first_row.values
# Out:
# array(['Statistician', '1876-06-13', '1937-10-16', 61], dtype=object)

# %%
first_row.index[0]
# Out:
# 'Occupation'

# %%
first_row.values[0]
# Out:
# 'Statistician'

# %%
type(first_row.index)
# Out:
# pandas.core.indexes.base.Index

# %%
type(first_row.values)
# Out:
# numpy.ndarray

# %%
scientists.index[0]
# Out:
# 'Rosaline Franklin'

# %%
scientists.values[0]
# Out:
# array(['Chemist', '1920-07-25', '1958-04-16', 37], dtype=object)

# %%
scientists.values
# Out:
# array([['Chemist', '1920-07-25', '1958-04-16', 37],
#        ['Statistician', '1876-06-13', '1937-10-16', 61]], dtype=object)

# %%
first_row.keys()
# Out:
# Index(['Occupation', 'Born', 'Died', 'Age'], dtype='object')

# %%
first = first_row.copy()
first
# Out:
# Occupation    Statistician
# Born            1876-06-13
# Died            1937-10-16
# Age                     61
# Name: William Gosset, dtype: object

# %%
first.keys()
# Out:
# Index(['Occupation', 'Born', 'Died', 'Age'], dtype='object')

# %%
first.keys()[0]
# Out:
# 'Occupation'

# %%
age = scientists['Age']
age
# Out:
# Rosaline Franklin    37
# William Gosset       61
# Name: Age, dtype: int64

# %%
type(age)
# Out:
# pandas.core.series.Series

# %%
age.index
# Out:
# Index(['Rosaline Franklin', 'William Gosset'], dtype='object')

# %%
age.min()
# Out:
# 37

# %%
age.max()
# Out:
# 61

# %%
age.std()
# Out:
# 16.97056274847714

# %%
age.median()
# Out:
# 49.0

# %%
age.count()
# Out:
# 2

# %%
age.nunique()
# Out:
# 2

# %%
sr1 = pd.Series([60], index = ['kim'])
sr1
# Out:
# kim    60
# dtype: int64

# %%
sr2 = pd.Series([70], index = ['lee'])
sr2
# Out:
# lee    70
# dtype: int64

# %%
sr12 = pd.concat([sr1, sr2])
sr12
# Out:
# kim    60
# lee    70
# dtype: int64

# %%
sr12.reset_index()
# Out:
#   index   0
# 0   kim  60
# 1   lee  70

# %%
df12 = pd.DataFrame(sr12).reset_index(names='col1')
df12
# Out:
#   col1   0
# 0  kim  60
# 1  lee  70

# %%
df12 = sr12.reset_index(name='A')
df12
# Out:
#   index   A
# 0   kim  60
# 1   lee  70

# %%
pd.Series.to_frame(sr12).reset_index()
# Out:
#   index   0
# 0   kim  60
# 1   lee  70

# %%
pd.DataFrame(sr12).reset_index(name='A')
# Out:
#      A   0
# 0  kim  60
# 1  lee  70

# %%
sr2
# Out:
# lee    70
# dtype: int64

# %%
sr12 = pd.concat([sr1, sr2])
sr12
# Out:
# kim    60
# lee    70
# dtype: int64

# %%
type(sr12)
# Out:
# pandas.core.series.Series

# %%
df1 = pd.Series.to_frame(sr1)
df2 = pd.Series.to_frame(sr2)
print(df1)
print(df2)
# Out:
#       0
# kim  60
#       0
# lee  70

# %%
df12 = pd.concat([df1, df2])
df12
# Out:
#       0
# kim  60
# lee  70

# %%
age.describe()
# Out:
# count     2.000000
# mean     49.000000
# std      16.970563
# min      37.000000
# 25%      43.000000
# 50%      49.000000
# 75%      55.000000
# max      61.000000
# Name: Age, dtype: float64

# %%
scientists.describe()
# Out:
#              Age
# count   2.000000
# mean   49.000000
# std    16.970563
# min    37.000000
# 25%    43.000000
# 50%    49.000000
# 75%    55.000000
# max    61.000000

# %%
df.tail()
# Out:
#        country continent  year  lifeExp       pop   gdpPercap
# 1699  Zimbabwe    Africa  1987   62.351   9216418  706.157306
# 1700  Zimbabwe    Africa  1992   60.377  10704340  693.420786
# 1701  Zimbabwe    Africa  1997   46.809  11404948  792.449960
# 1702  Zimbabwe    Africa  2002   39.989  11926563  672.038623
# 1703  Zimbabwe    Africa  2007   43.487  12311143  469.709298

# %%
df['year'].drop_duplicates()
# Out:
# 0     1952
# 1     1957
# 2     1962
# 3     1967
# 4     1972
# 5     1977
# 6     1982
# 7     1987
# 8     1992
# 9     1997
# 10    2002
# 11    2007
# Name: year, dtype: int64

# %%
sr1.equals(sr2)
# Out:
# False

# %%
sr1.equals(sr1)
# Out:
# True

# %%
age
# Out:
# Rosaline Franklin    37
# William Gosset       61
# Name: Age, dtype: int64

# %%
age.isin([37,60])
# Out:
# Rosaline Franklin     True
# William Gosset       False
# Name: Age, dtype: bool

# %%
scientists
# Out:
#                      Occupation        Born        Died  Age
# Rosaline Franklin       Chemist  1920-07-25  1958-04-16   37
# William Gosset     Statistician  1876-06-13  1937-10-16   61

# %%
Occu = scientists['Occupation']
Occu.isin(['Chemist'])
# Out:
# Rosaline Franklin     True
# William Gosset       False
# Name: Occupation, dtype: bool

# %%
age.replace(37, 30)
# Out:
# Rosaline Franklin    30
# William Gosset       61
# Name: Age, dtype: int64

# %%
df.sample(10)
# Out:
#           country continent  year  lifeExp       pop     gdpPercap
# 1283      Romania    Europe  2007   72.476  22276056  10808.475610
# 283         Chile  Americas  1987   72.492  12463354   5547.063754
# 1678  Yemen, Rep.      Asia  2002   60.308  18701257   2234.820827
# 1516     Tanzania    Africa  1972   47.620  14706593    915.985059
# 1042   Mozambique    Africa  2002   44.026  18473780    633.617947
# 819         Kenya    Africa  1967   50.654  10191512   1056.736457
# 1288       Rwanda    Africa  1972   44.600   3992121    590.580664
# 421      Djibouti    Africa  1957   37.328     71851   2864.969076
# 108       Belgium    Europe  1952   68.000   8730405   8343.105127
# 1496        Syria      Asia  1992   69.249  13219062   3340.542768

# %%
age.sample(2)
# Out:
# Rosaline Franklin    37
# William Gosset       61
# Name: Age, dtype: int64

# %%
df.equals(df1)
# Out:
# False

# %%
df.head()
# Out:
#        country continent  year  lifeExp       pop   gdpPercap
# 0  Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4  Afghanistan      Asia  1972   36.088  13079460  739.981106

# %%
df.isin(['Asia', 1967])
# Out:
#       country  continent   year  lifeExp    pop  gdpPercap
# 0       False       True  False    False  False      False
# 1       False       True  False    False  False      False
# 2       False       True  False    False  False      False
# 3       False       True   True    False  False      False
# 4       False       True  False    False  False      False
# ...       ...        ...    ...      ...    ...        ...
# 1699    False      False  False    False  False      False
# 1700    False      False  False    False  False      False
# 1701    False      False  False    False  False      False
# 1702    False      False  False    False  False      False
# 1703    False      False  False    False  False      False
#
# [1704 rows x 6 columns]

# %%
df_sample = df.head()
df_sample
# Out:
#        country continent  year  lifeExp       pop   gdpPercap
# 0  Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4  Afghanistan      Asia  1972   36.088  13079460  739.981106

# %%
df_sample.replace('Asia', 'AS')
# Out:
#        country continent  year  lifeExp       pop   gdpPercap
# 0  Afghanistan        AS  1952   28.801   8425333  779.445314
# 1  Afghanistan        AS  1957   30.332   9240934  820.853030
# 2  Afghanistan        AS  1962   31.997  10267083  853.100710
# 3  Afghanistan        AS  1967   34.020  11537966  836.197138
# 4  Afghanistan        AS  1972   36.088  13079460  739.981106

# %%
df_sample = df.sample(10).sort_index()
df_sample
# Out:
#            country continent  year  lifeExp        pop     gdpPercap
# 55       Argentina  Americas  1987   70.774   31620918   9139.671389
# 139        Bolivia  Americas  1987   57.251    6156369   2753.691490
# 302       Colombia  Americas  1962   57.863   17009885   2492.351109
# 429       Djibouti    Africa  1997   53.157     417908   1895.016984
# 748        Ireland    Europe  1972   71.280    3024400   9530.772896
# 779          Italy    Europe  2007   80.546   58147733  28569.719700
# 802          Japan      Asia  2002   82.000  127065841  28604.591900
# 1345  Sierra Leone    Africa  1957   31.570    2295678   1004.484437
# 1380      Slovenia    Europe  1952   65.570    1489518   4215.041741
# 1682        Zambia    Africa  1962   46.023    3421000   1452.725766

# %%
sr_sample = df_sample['country'].sort_index(ascending=False)
sr_sample
# Out:
# 1682          Zambia
# 1380        Slovenia
# 1345    Sierra Leone
# 802            Japan
# 779            Italy
# 748          Ireland
# 429         Djibouti
# 302         Colombia
# 139          Bolivia
# 55         Argentina
# Name: country, dtype: object

# %%
sr_sample.to_frame()
# Out:
#            country
# 1682        Zambia
# 1380      Slovenia
# 1345  Sierra Leone
# 802          Japan
# 779          Italy
# 748        Ireland
# 429       Djibouti
# 302       Colombia
# 139        Bolivia
# 55       Argentina

# %%
age.sort_values(ascending = False)
# Out:
# William Gosset       61
# Rosaline Franklin    37
# Name: Age, dtype: int64

# %%
scientists_raw = pd.read_csv('scientists.csv')
scientists = scientists_raw.copy()
scientists.head()
# Out:
#                    Name        Born        Died  Age    Occupation
# 0     Rosaline Franklin  1920-07-25  1958-04-16   37       Chemist
# 1        William Gosset  1876-06-13  1937-10-16   61  Statistician
# 2  Florence Nightingale  1820-05-12  1910-08-13   90         Nurse
# 3           Marie Curie  1867-11-07  1934-07-04   66       Chemist
# 4         Rachel Carson  1907-05-27  1964-04-14   56     Biologist

# %%
scientists.shape
# Out:
# (8, 5)

# %%
scientists.describe()
# Out:
#              Age
# count   8.000000
# mean   59.125000
# std    18.325918
# min    37.000000
# 25%    44.000000
# 50%    58.500000
# 75%    68.750000
# max    90.000000

# %%
scientists.describe(include='all')
# Out:
#                      Name        Born        Died        Age Occupation
# count                   8           8           8   8.000000          8
# unique                  8           8           8        NaN          7
# top     Rosaline Franklin  1920-07-25  1958-04-16        NaN    Chemist
# freq                    1           1           1        NaN          2
# mean                  NaN         NaN         NaN  59.125000        NaN
# std                   NaN         NaN         NaN  18.325918        NaN
# min                   NaN         NaN         NaN  37.000000        NaN
# 25%                   NaN         NaN         NaN  44.000000        NaN
# 50%                   NaN         NaN         NaN  58.500000        NaN
# 75%                   NaN         NaN         NaN  68.750000        NaN
# max                   NaN         NaN         NaN  90.000000        NaN

# %%
ages = scientists['Age']
ages
# Out:
# 0    37
# 1    61
# 2    90
# 3    66
# 4    56
# 5    45
# 6    41
# 7    77
# Name: Age, dtype: int64

# %%
ages[ages > ages.mean()]
# Out:
# 1    61
# 2    90
# 3    66
# 7    77
# Name: Age, dtype: int64

# %%
ages > ages.mean()
# Out:
# 0    False
# 1     True
# 2     True
# 3     True
# 4    False
# 5    False
# 6    False
# 7     True
# Name: Age, dtype: bool

# %%
ages > 10
# Out:
# 0    True
# 1    True
# 2    True
# 3    True
# 4    True
# 5    True
# 6    True
# 7    True
# Name: Age, dtype: bool

# %%
ages + ages
# Out:
# 0     74
# 1    122
# 2    180
# 3    132
# 4    112
# 5     90
# 6     82
# 7    154
# Name: Age, dtype: int64

# %%
ages * ages
# Out:
# 0    1369
# 1    3721
# 2    8100
# 3    4356
# 4    3136
# 5    2025
# 6    1681
# 7    5929
# Name: Age, dtype: int64

# %%
ages * 100
# Out:
# 0    3700
# 1    6100
# 2    9000
# 3    6600
# 4    5600
# 5    4500
# 6    4100
# 7    7700
# Name: Age, dtype: int64

# %%
ages + 100
# Out:
# 0    137
# 1    161
# 2    190
# 3    166
# 4    156
# 5    145
# 6    141
# 7    177
# Name: Age, dtype: int64

# %%
scientists[scientists['Age'] > scientists['Age'].mean()]
# Out:
#                    Name        Born        Died  Age     Occupation
# 1        William Gosset  1876-06-13  1937-10-16   61   Statistician
# 2  Florence Nightingale  1820-05-12  1910-08-13   90          Nurse
# 3           Marie Curie  1867-11-07  1934-07-04   66        Chemist
# 7          Johann Gauss  1777-04-30  1855-02-23   77  Mathematician

# %%
scientists * 2
# Out:
#                                        Name                  Born  \
# 0        Rosaline FranklinRosaline Franklin  1920-07-251920-07-25
# 1              William GossetWilliam Gosset  1876-06-131876-06-13
# 2  Florence NightingaleFlorence Nightingale  1820-05-121820-05-12
# 3                    Marie CurieMarie Curie  1867-11-071867-11-07
# 4                Rachel CarsonRachel Carson  1907-05-271907-05-27
# 5                        John SnowJohn Snow  1813-03-151813-03-15
# 6                    Alan TuringAlan Turing  1912-06-231912-06-23
# 7                  Johann GaussJohann Gauss  1777-04-301777-04-30
#
#                    Died  Age                            Occupation
# 0  1958-04-161958-04-16   74                        ChemistChemist
# 1  1937-10-161937-10-16  122              StatisticianStatistician
# 2  1910-08-131910-08-13  180                            NurseNurse
# 3  1934-07-041934-07-04  132                        ChemistChemist
# ...

# %%
scientists + scientists
# Out:
#                                        Name                  Born  \
# 0        Rosaline FranklinRosaline Franklin  1920-07-251920-07-25
# 1              William GossetWilliam Gosset  1876-06-131876-06-13
# 2  Florence NightingaleFlorence Nightingale  1820-05-121820-05-12
# 3                    Marie CurieMarie Curie  1867-11-071867-11-07
# 4                Rachel CarsonRachel Carson  1907-05-271907-05-27
# 5                        John SnowJohn Snow  1813-03-151813-03-15
# 6                    Alan TuringAlan Turing  1912-06-231912-06-23
# 7                  Johann GaussJohann Gauss  1777-04-301777-04-30
#
#                    Died  Age                            Occupation
# 0  1958-04-161958-04-16   74                        ChemistChemist
# 1  1937-10-161937-10-16  122              StatisticianStatistician
# 2  1910-08-131910-08-13  180                            NurseNurse
# 3  1934-07-041934-07-04  132                        ChemistChemist
# ...

# %%
scientists.dtypes
# Out:
# Name          object
# Born          object
# Died          object
# Age            int64
# Occupation    object
# dtype: object

# %%
print(scientists['Age'].dtype)
# Out:
# int64

# %%
pd.to_datetime(scientists['Born'], format = '%Y-%m-%d')
# Out:
# 0   1920-07-25
# 1   1876-06-13
# 2   1820-05-12
# 3   1867-11-07
# 4   1907-05-27
# 5   1813-03-15
# 6   1912-06-23
# 7   1777-04-30
# Name: Born, dtype: datetime64[ns]

# %%
scientists
# Out:
#                    Name        Born        Died  Age          Occupation
# 0     Rosaline Franklin  1920-07-25  1958-04-16   37             Chemist
# 1        William Gosset  1876-06-13  1937-10-16   61        Statistician
# 2  Florence Nightingale  1820-05-12  1910-08-13   90               Nurse
# 3           Marie Curie  1867-11-07  1934-07-04   66             Chemist
# 4         Rachel Carson  1907-05-27  1964-04-14   56           Biologist
# 5             John Snow  1813-03-15  1858-06-16   45           Physician
# 6           Alan Turing  1912-06-23  1954-06-07   41  Computer Scientist
# 7          Johann Gauss  1777-04-30  1855-02-23   77       Mathematician

# %%
scientists.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Name        8 non-null      object
#  1   Born        8 non-null      object
#  2   Died        8 non-null      object
#  3   Age         8 non-null      int64
#  4   Occupation  8 non-null      object
# dtypes: int64(1), object(4)
# memory usage: 452.0+ bytes

# %%
born_datetime = pd.to_datetime(scientists['Born'], format = '%Y-%m-%d')
born_datetime
# Out:
# 0   1920-07-25
# 1   1876-06-13
# 2   1820-05-12
# 3   1867-11-07
# 4   1907-05-27
# 5   1813-03-15
# 6   1912-06-23
# 7   1777-04-30
# Name: Born, dtype: datetime64[ns]

# %%
died_datetime = pd.to_datetime(scientists['Died'], format = '%Y-%m-%d')
died_datetime
# Out:
# 0   1958-04-16
# 1   1937-10-16
# 2   1910-08-13
# 3   1934-07-04
# 4   1964-04-14
# 5   1858-06-16
# 6   1954-06-07
# 7   1855-02-23
# Name: Died, dtype: datetime64[ns]

# %%
scientists['Born_dt'], scientists['Died_dt'] = born_datetime, died_datetime
scientists
# Out:
#                    Name        Born        Died  Age          Occupation  \
# 0     Rosaline Franklin  1920-07-25  1958-04-16   37             Chemist
# 1        William Gosset  1876-06-13  1937-10-16   61        Statistician
# 2  Florence Nightingale  1820-05-12  1910-08-13   90               Nurse
# 3           Marie Curie  1867-11-07  1934-07-04   66             Chemist
# 4         Rachel Carson  1907-05-27  1964-04-14   56           Biologist
# 5             John Snow  1813-03-15  1858-06-16   45           Physician
# 6           Alan Turing  1912-06-23  1954-06-07   41  Computer Scientist
# 7          Johann Gauss  1777-04-30  1855-02-23   77       Mathematician
#
#      Born_dt    Died_dt
# 0 1920-07-25 1958-04-16
# 1 1876-06-13 1937-10-16
# 2 1820-05-12 1910-08-13
# 3 1867-11-07 1934-07-04
# 4 1907-05-27 1964-04-14
# 5 1813-03-15 1858-06-16
# 6 1912-06-23 1954-06-07
# 7 1777-04-30 1855-02-23

# %%
scientists.shape
# Out:
# (8, 7)

# %%
import random
random.seed(42)

# %%
scientists['Age']
# Out:
# 0    77
# 1    61
# 2    41
# 3    66
# 4    90
# 5    37
# 6    45
# 7    56
# Name: Age, dtype: int64

# %%
random.shuffle(scientists['Age'])

# %%
scientists['Age']
# Out:
# 0    37
# 1    56
# 2    45
# 3    90
# 4    77
# 5    41
# 6    66
# 7    61
# Name: Age, dtype: int64

# %%
scientists
# Out:
#                    Name        Born        Died  Age          Occupation  \
# 0     Rosaline Franklin  1920-07-25  1958-04-16   90             Chemist
# 1        William Gosset  1876-06-13  1937-10-16   66        Statistician
# 2  Florence Nightingale  1820-05-12  1910-08-13   61               Nurse
# 3           Marie Curie  1867-11-07  1934-07-04   77             Chemist
# 4         Rachel Carson  1907-05-27  1964-04-14   56           Biologist
# 5             John Snow  1813-03-15  1858-06-16   45           Physician
# 6           Alan Turing  1912-06-23  1954-06-07   41  Computer Scientist
# 7          Johann Gauss  1777-04-30  1855-02-23   37       Mathematician
#
#      Born_dt    Died_dt
# 0 1920-07-25 1958-04-16
# 1 1876-06-13 1937-10-16
# 2 1820-05-12 1910-08-13
# 3 1867-11-07 1934-07-04
# 4 1907-05-27 1964-04-14
# 5 1813-03-15 1858-06-16
# 6 1912-06-23 1954-06-07
# 7 1777-04-30 1855-02-23

# %%
scientists_drop = scientists.drop(['Born', 'Died'], axis=1)

# %%
scientists_drop
# Out:
#                    Name  Age          Occupation    Born_dt    Died_dt
# 0     Rosaline Franklin   90             Chemist 1920-07-25 1958-04-16
# 1        William Gosset   66        Statistician 1876-06-13 1937-10-16
# 2  Florence Nightingale   61               Nurse 1820-05-12 1910-08-13
# 3           Marie Curie   77             Chemist 1867-11-07 1934-07-04
# 4         Rachel Carson   56           Biologist 1907-05-27 1964-04-14
# 5             John Snow   45           Physician 1813-03-15 1858-06-16
# 6           Alan Turing   41  Computer Scientist 1912-06-23 1954-06-07
# 7          Johann Gauss   37       Mathematician 1777-04-30 1855-02-23

# %%
scientists_drop2 = scientists.drop(columns = ['Born_dt', 'Died_dt'])
scientists_drop2
# Out:
#                    Name        Born        Died  Age          Occupation
# 0     Rosaline Franklin  1920-07-25  1958-04-16   90             Chemist
# 1        William Gosset  1876-06-13  1937-10-16   66        Statistician
# 2  Florence Nightingale  1820-05-12  1910-08-13   61               Nurse
# 3           Marie Curie  1867-11-07  1934-07-04   77             Chemist
# 4         Rachel Carson  1907-05-27  1964-04-14   56           Biologist
# 5             John Snow  1813-03-15  1858-06-16   45           Physician
# 6           Alan Turing  1912-06-23  1954-06-07   41  Computer Scientist
# 7          Johann Gauss  1777-04-30  1855-02-23   37       Mathematician

# %%
scientists_pickle = pd.read_pickle('scientists_names_series.pickle')
scientists_pickle
# Out:
# 0       Rosaline Franklin
# 1          William Gosset
# 2    Florence Nightingale
# 3             Marie Curie
# 4           Rachel Carson
# 5               John Snow
# 6             Alan Turing
# 7            Johann Gauss
# Name: Name, dtype: object

# %%
names = scientists['Name']
names
# Out:
# 0       Rosaline Franklin
# 1          William Gosset
# 2    Florence Nightingale
# 3             Marie Curie
# 4           Rachel Carson
# 5               John Snow
# 6             Alan Turing
# 7            Johann Gauss
# Name: Name, dtype: object

# %%
scientists.to_pickle('scientists_df.pickle')

# %%
temp = pd.read_pickle('scientists_df.pickle')
temp
# Out:
#                    Name        Born        Died  Age          Occupation  \
# 0     Rosaline Franklin  1920-07-25  1958-04-16   90             Chemist
# 1        William Gosset  1876-06-13  1937-10-16   66        Statistician
# 2  Florence Nightingale  1820-05-12  1910-08-13   61               Nurse
# 3           Marie Curie  1867-11-07  1934-07-04   77             Chemist
# 4         Rachel Carson  1907-05-27  1964-04-14   56           Biologist
# 5             John Snow  1813-03-15  1858-06-16   45           Physician
# 6           Alan Turing  1912-06-23  1954-06-07   41  Computer Scientist
# 7          Johann Gauss  1777-04-30  1855-02-23   37       Mathematician
#
#      Born_dt    Died_dt
# 0 1920-07-25 1958-04-16
# 1 1876-06-13 1937-10-16
# 2 1820-05-12 1910-08-13
# 3 1867-11-07 1934-07-04
# 4 1907-05-27 1964-04-14
# 5 1813-03-15 1858-06-16
# 6 1912-06-23 1954-06-07
# 7 1777-04-30 1855-02-23

# %%
names.to_pickle('test_names.pickle')

# %%
temp.to_pickle('test_df.pickle')

# %%
# !pip install openpyxl
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 250.0/250.0 kB 5.3 MB/s eta 0:00:000:00:01
# ...

# %%
import openpyxl

# %%
names
# Out:
# 0       Rosaline Franklin
# 1          William Gosset
# 2    Florence Nightingale
# 3             Marie Curie
# 4           Rachel Carson
# 5               John Snow
# 6             Alan Turing
# 7            Johann Gauss
# Name: Name, dtype: object

# %%
names_df = names.to_frame()
names_df
# Out:
#                    Name
# 0     Rosaline Franklin
# 1        William Gosset
# 2  Florence Nightingale
# 3           Marie Curie
# 4         Rachel Carson
# 5             John Snow
# 6           Alan Turing
# 7          Johann Gauss

# %%
names_df.to_excel('test_excel.xlsx')

# %%
names_df.to_excel('test_excel2.xlsx', index=False)

# %%
names.to_excel('test_excel3.xlsx', index=False)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
ans_raw = sns.load_dataset('anscombe')
ans = ans_raw.copy()
ans.head()
# Out:
#   dataset     x     y
# 0       I  10.0  8.04
# 1       I   8.0  6.95
# 2       I  13.0  7.58
# 3       I   9.0  8.81
# 4       I  11.0  8.33

# %%
ans.shape
# Out:
# (44, 3)

# %%
ans['dataset'].unique()
# Out:
# array(['I', 'II', 'III', 'IV'], dtype=object)

# %%
dataset_1 = ans[ans['dataset']=='I']
dataset_1
# Out:
#    dataset     x      y
# 0        I  10.0   8.04
# 1        I   8.0   6.95
# 2        I  13.0   7.58
# 3        I   9.0   8.81
# 4        I  11.0   8.33
# 5        I  14.0   9.96
# 6        I   6.0   7.24
# 7        I   4.0   4.26
# 8        I  12.0  10.84
# 9        I   7.0   4.82
# 10       I   5.0   5.68

# %%
dataset_1.plot(rot=45);

# %%
plt.plot(dataset_1['x'], dataset_1['y']);

# %%
fig = plt.figure()
ax1 = fig.add_subplot(1,1,1)

# %%
ax1.hist(tips['total_bill'], bins=20)
ax1.set_title('Line')
ax1.set_xlabel('X-label')
ax1.set_ylabel('Y-label')
fig

# %%
plt.plot(dataset_1['x'], dataset_1['y'], 'o');

# %%
dataset_2 = ans[ans['dataset'] == 'II']
dataset_3 = ans[ans['dataset'] == 'III']
dataset_4 = ans[ans['dataset'] == 'IV']

# %%
fig = plt.figure()
ax1 = fig.add_subplot(2, 2, 1)
ax2 = fig.add_subplot(2, 2, 2)
ax3 = fig.add_subplot(2, 2, 3)
ax4 = fig.add_subplot(2, 2, 4)

# %%
ax1.plot(dataset_1['x'], dataset_1['y'], 'o')
ax2.plot(dataset_2['x'], dataset_2['y'], 'o')
ax3.plot(dataset_3['x'], dataset_3['y'], 'o')
ax4.plot(dataset_4['x'], dataset_4['y'], 'o')
fig

# %%
ax1.set_title('D1')
ax2.set_title('D2')
ax3.set_title('D3')
ax4.set_title('D4')
fig.suptitle('Anscombe Data2')
fig.tight_layout()
fig

# %%
tips = sns.load_dataset('tips')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips.shape
# Out:
# (244, 7)

# %%
tips.describe(include='all')
# Out:
#         total_bill         tip   sex smoker  day    time        size
# count   244.000000  244.000000   244    244  244     244  244.000000
# unique         NaN         NaN     2      2    4       2         NaN
# top            NaN         NaN  Male     No  Sat  Dinner         NaN
# freq           NaN         NaN   157    151   87     176         NaN
# mean     19.785943    2.998279   NaN    NaN  NaN     NaN    2.569672
# std       8.902412    1.383638   NaN    NaN  NaN     NaN    0.951100
# min       3.070000    1.000000   NaN    NaN  NaN     NaN    1.000000
# 25%      13.347500    2.000000   NaN    NaN  NaN     NaN    2.000000
# 50%      17.795000    2.900000   NaN    NaN  NaN     NaN    2.000000
# 75%      24.127500    3.562500   NaN    NaN  NaN     NaN    3.000000
# max      50.810000   10.000000   NaN    NaN  NaN     NaN    6.000000

# %%
fig = plt.figure()
ax1 = fig.add_subplot(1,1,1)

# %%
ax1.scatter(tips['total_bill'], tips['tip'])
ax1.set_title('Scatterplot of Totla Bill vs. Tip')
ax1.set_xlabel('Total Bill')
ax1.set_ylabel('Tip')
fig

# %%
fig = plt.figure()
ax1 = fig.add_subplot(1,1,1)

# %%
ax1.boxplot([tips[tips['sex']=='Female']['tip'],
             tips[tips['sex']=='Male']['tip']],
            labels = ['Famale', 'Male'])
ax1.set_title('Boxplot of Tips by Sex')
ax1.set_xlabel('Sex')
ax1.set_ylabel('Tip')
fig

# %%
def recode_sex(sex):
    if sex == 'Female':
        return 0
    else:
        return 1

# %%
tips['sex_color'] = tips['sex'].apply(recode_sex)
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size sex_color
# 0       16.99  1.01  Female     No  Sun  Dinner     2         0
# 1       10.34  1.66    Male     No  Sun  Dinner     3         1
# 2       21.01  3.50    Male     No  Sun  Dinner     3         1
# 3       23.68  3.31    Male     No  Sun  Dinner     2         1
# 4       24.59  3.61  Female     No  Sun  Dinner     4         0

# %%
fig = plt.figure()
ax1 = fig.add_subplot(1,1,1)

# %%
ax1.scatter(x = tips['total_bill'],
            y = tips['tip'],
            s = tips['size'] * 10,
            c = tips['sex_color'],
            alpha = 0.5)
ax1.set_title('Total bill')
ax1.set_xlabel('bill')
ax1.set_ylabel('tip')
fig

# %%
def digit_sex(sex):
    if sex == 'Female':
        return 0
    elif sex == 'Male':
        return 1
    else:
        return 9

# %%
df = pd.DataFrame({'id'   : [1, 2, 3],
                   'name' : ['Kim', 'Lee', 'Park'],
                   'sex'  : ['Female', 'NoInfo', 'Male']})
df
# Out:
#    id  name     sex
# 0   1   Kim  Female
# 1   2   Lee  NoInfo
# 2   3  Park    Male

# %%
df['sex_code'] = df['sex'].apply(digit_sex)
df
# Out:
#    id  name     sex  sex_code
# 0   1   Kim  Female         0
# 1   2   Lee  NoInfo         9
# 2   3  Park    Male         1

# %%
ax = plt.subplots()
ax = sns.distplot(tips['total_bill'])
ax.set_title('Total bill')
# Out:
# /var/folders/ly/l_64txv96mz27r43l8jt9jx00000gn/T/ipykernel_1146/2272421692.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(tips['total_bill'])
# Text(0.5, 1.0, 'Total bill')

# %%
ax = plt.subplots()
ax = sns.kdeplot(tips['total_bill'])
ax.set_title('Total bill')
ax.set_xlabel('total billing')
ax.set_ylabel('how much')
# Out:
# Text(0, 0.5, 'how much')

# %%
ax = plt.subplots()
ax = sns.countplot(data = tips, x = 'day')

# %%
ax = plt.subplots()
ax = sns.regplot(data = tips, x = 'total_bill', y = 'tip', fit_reg = False)

# %%
joint = sns.jointplot(data = tips, x = 'total_bill', y = 'tip')
joint.set_axis_labels(xlabel = 'Total', ylabel = 'Tip')
joint.fig.suptitle('Joint', fontsize = 15, y = 1.03)
# Out:
# Text(0.5, 1.03, 'Joint')

# %%
hex = sns.jointplot(data = tips, x = 'total_bill', y = 'tip', kind = 'hex')
hex.set_axis_labels(xlabel = 'Total', ylabel = 'Tip')
hex.fig.suptitle('Title', fontsize = 15, y = 1.03)
# Out:
# Text(0.5, 1.03, 'Title')

# %%
ax1 = plt.subplots()
ax1 = sns.kdeplot(data = tips, x = 'total_bill', y = 'tip', fill= True)
ax1.set_title('Title')
ax1.set_xlabel('Total bill')
ax1.set_ylabel('Tip')
# Out:
# Text(0, 0.5, 'Tip')

# %%
ax = plt.subplots()
ax = sns.barplot(data = tips, x = 'time', y = 'total_bill')

# %%
fig = plt.subplots(2,2)
fig = sns.violinplot(data = tips, x = 'time', y = 'total_bill')

# %%
fig = sns.pairplot(tips)

# %%
fig = sns.PairGrid(tips)
fig.map_upper(sns.regplot)
fig.map_lower(sns.kdeplot)
fig.map_diag(sns.histplot)

# %%
viol = sns.violinplot(data = tips, x = 'time', y = 'total_bill', hue = 'sex', split = False)

# %%
scat = sns.lmplot(data = tips, x = 'total_bill', y = 'tip', hue = 'sex', fit_reg = True)

# %%
fig = sns.pairplot(data = tips, hue = 'sex')

# %%
ax = sns.lmplot(data = tips, x = 'total_bill', y = 'tip', hue = 'sex', fit_reg = False,
                markers = ['o', 'x'])

# %%
aplot = sns.lmplot(data = ans, x = 'x', y='y', fit_reg=False)

# %%
aplot = sns.lmplot(data = ans, x = 'x', y='y', fit_reg=False,
                   col = 'dataset', col_wrap=3)

# %%
import pandas as pd
import os
import matplotlib.pyplot as plt
import seaborn as sns

# %%
path = os.getcwd()
path
# Out:
# 'C:\\Users\\kiip\\Documents\\github\\doit_pandas'

# %%
os.chdir(path + '\\data')
os.getcwd()
# Out:
# 'C:\\Users\\kiip\\Documents\\github\\doit_pandas\\data'

# %%
tips = sns.load_dataset('tips')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
facet = sns.FacetGrid(data=tips, col='time')
facet = facet.map(sns.histplot, 'total_bill')

# %%
facet = sns.FacetGrid(data=tips, col='time', row='smoker', hue='sex')
facet = facet.map(plt.scatter, 'total_bill', 'tip').add_legend()

# %%
tips['total_bill'].plot.hist();

# %%
ax = tips[['total_bill', 'tip']].plot.hist(alpha=0.5, bins=20)

# %%
# !pip install scipy
# Out:
# ...
#      ---------------------------------------- 0.0/60.4 kB ? eta -:--:--
#      ------------ ------------------------- 20.5/60.4 kB 320.0 kB/s eta 0:00:01
#      -------------------------------------- 60.4/60.4 kB 796.9 kB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/46.2 MB ? eta -:--:--
#    ---------------------------------------- 0.3/46.2 MB 6.3 MB/s eta 0:00:08
#     --------------------------------------- 0.8/46.2 MB 8.0 MB/s eta 0:00:06
#    - -------------------------------------- 1.3/46.2 MB 10.0 MB/s eta 0:00:05
#    - -------------------------------------- 1.6/46.2 MB 9.3 MB/s eta 0:00:05
#    - -------------------------------------- 2.1/46.2 MB 9.8 MB/s eta 0:00:05
#    -- ------------------------------------- 2.7/46.2 MB 10.1 MB/s eta 0:00:05
#    -- ------------------------------------- 3.2/46.2 MB 10.2 MB/s eta 0:00:05
#    --- ------------------------------------ 3.7/46.2 MB 10.4 MB/s eta 0:00:05
# ...

# %%
import scipy

# %%
ax = plt.subplots()
ax = tips['tip'].plot.kde()

# %%
fig = plt.figure()

sns_style = ['whitegrid', 'darkgrid', 'white', 'dark', 'ticks']

for idx, style in enumerate(sns_style):
    plot_position = idx+1
    with sns.axes_style(style):
        ax = fig.add_subplot(2, 3, plot_position)
        violin = sns.violinplot(data=tips, x='time', y='total_bill', ax=ax)
        violin.set_title(style)

fig.tight_layout()
